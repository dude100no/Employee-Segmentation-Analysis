# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv('Company_Employee.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Age                                             1470 non-null   int64
#  1   Gender                                          1470 non-null   object
#  2   BusinessTravel                                  1470 non-null   object
#  3   Job Function                                    1470 non-null   object
#  4   Distance Between Company and Home (KM)          1470 non-null   int64
#  5   Education (1 is lowest, 5 is highest)           1470 non-null   int64
#  6   Job Satisfaction (1 is lowest, 4 is highest)    1470 non-null   int64
#  7   MaritalStatus                                   1470 non-null   object
#  8   Salary ($)                                      1470 non-null   int64
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Zero null values

# %%
df.isnull().sum()
# Out:
# Age                                               0
# Gender                                            0
# BusinessTravel                                    0
# Job Function                                      0
# Distance Between Company and Home (KM)            0
# Education (1 is lowest, 5 is highest)             0
# Job Satisfaction (1 is lowest, 4 is highest)      0
# MaritalStatus                                     0
# Salary ($)                                        0
# Performance Rating (1 is lowest, 4 is highest)    0
# Work Life Balance (1 is worst, 4 is best)         0
# Length of Service (Years)                         0
# Resign Status                                     0
# dtype: int64

# %% [markdown]
# Imbalanced Dataset does not matter for Unsupervised Learning

# %%
fig, ax = plt.subplots(3, 2, figsize=(10,10))

sns.countplot(data=df, x='Resign Status', ax=ax[0,0])
sns.countplot(data=df, x='Gender', ax=ax[0,1])
sns.countplot(data=df, x='BusinessTravel', ax=ax[1,0])
sns.countplot(data=df, x='Job Function', ax=ax[1,1])
sns.countplot(data=df, x='MaritalStatus', ax=ax[2,0])

# sns.countplot(df['Resign Status'], ax=ax[0,0])
# sns.countplot(df['Gender'], ax=ax[0,1])
# sns.countplot(df['BusinessTravel'], ax=ax[1,0])
# sns.countplot(df['Job Function'], ax=ax[1,1])
# sns.countplot(df['MaritalStatus'], ax=ax[2,0])

fig.show()
# Out:
# C:\Users\Aloysius Koh\AppData\Local\Temp\ipykernel_33764\3989135373.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
